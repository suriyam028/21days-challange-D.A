# %% [markdown]
# <a href="https://colab.research.google.com/github/suriyam028/21days-challange-D.A/blob/main/Python_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tuple1 = (10, 20, 30)
tuple2 = (40, 50, 60)
t_combine = tuple1 + tuple2
print(t_combine)
print(t_combine * 3)
print(t_combine[2])
print(t_combine[:3])
print(t_combine[-3:])
# Out:
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# 30
# (10, 20, 30)
# (40, 50, 60)

# %%
strM = "Python beginner tutorial"
print(strM.upper())
print(strM.lower())
print(strM.capitalize())
print(strM.count('t'))
print(strM.replace("Python", "Machine Learning"))
# Out:
# PYTHON BEGINNER TUTORIAL
# python beginner tutorial
# Python beginner tutorial
# 3
# Machine Learning beginner tutorial

# %%
print(final_string[0])
print(final_string[-1])
print(final_string[:5])
print(final_string[-11:])
print(final_string[::-1])
print(final_string[25:31])
# Out:
# H
# g
# Hello
# programming
# gnimmargorp nohtyP ot emoclew ,ayiruS olleH
# Python

# %%
string1 = "Hello "

name = input("Enter your Name: ")

result = string1 + name

print(result)
string3 = ", welcome to Python programming"

final_string = result + string3

print(final_string)
# Out:
# Enter your Name: Suriya
# Hello Suriya
# Hello Suriya, welcome to Python programming
