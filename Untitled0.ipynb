# %% [markdown]
# <a href="https://colab.research.google.com/github/suriyam028/21days-challange-D.A/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_bmi(weight, height):
    return weight / (height ** 2)

weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))

bmi = calculate_bmi(weight, height)

print("Your BMI is:", round(bmi, 2))
# Out:
# Enter your weight in kg: 75
# Enter your height in meters: 1.72
# Your BMI is: 25.35

# %%
num = int(input("Enter the number for multiplication table: "))

for i in range(1, 11):
    print(num, "x", i, "=", num * i)
# Out:
# Enter the number for multiplication table: 10
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100

# %%
import random

secret_number = random.randint(1, 10)
attempts = 3

while attempts > 0:
    guess = int(input("Guess the number (between 1 and 10): "))

    if guess < 1 or guess > 10:
        print("Your guess is out of range. Please guess between 1 and 10.")
        continue

    if guess == secret_number:
        print("Congratulations! You guessed the correct number.")
        break
    elif guess > secret_number:
        print("Too high. Try again.")
    else:
        print("Too low. Try again.")

    attempts -= 1

else:
    print("Better luck next time!")
# Out:
# Guess the number (between 1 and 10): 2
# Too low. Try again.
# Guess the number (between 1 and 10): 8
# Congratulations! You guessed the correct number.
